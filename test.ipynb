# %%
from data_loader.vox_celeb2.main import get_train_list

train_path = "datasets/test/id00528"
train_list_path = "datasets/train_list.txt"

train_list = get_train_list("./datasets")

# %%
train_list["id00528"]
# Out:
# {'8xGpzHcjXXM': [{'file_id': '00001',
#    'video_path': 'id00528/8xGpzHcjXXM/00001.mp4',
#    'audio_path': 'id00528/8xGpzHcjXXM/00001.wav'}],
#  'E0tw0gNxEjs': [{'file_id': '00002',
#    'video_path': 'id00528/E0tw0gNxEjs/00002.mp4',
#    'audio_path': 'id00528/E0tw0gNxEjs/00002.wav'}],
#  'G1H52Y68uKU': [{'file_id': '00003',
#    'video_path': 'id00528/G1H52Y68uKU/00003.mp4',
#    'audio_path': 'id00528/G1H52Y68uKU/00003.wav'},
#   {'file_id': '00004',
#    'video_path': 'id00528/G1H52Y68uKU/00004.mp4',
#    'audio_path': 'id00528/G1H52Y68uKU/00004.wav'}],
#  'GpB5i41hye4': [{'file_id': '00005',
#    'video_path': 'id00528/GpB5i41hye4/00005.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00005.wav'},
#   {'file_id': '00006',
#    'video_path': 'id00528/GpB5i41hye4/00006.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00006.wav'},
#   {'file_id': '00007',
#    'video_path': 'id00528/GpB5i41hye4/00007.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00007.wav'},
#   {'file_id': '00008',
#    'video_path': 'id00528/GpB5i41hye4/00008.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00008.wav'},
#   {'file_id': '00009',
#    'video_path': 'id00528/GpB5i41hye4/00009.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00009.wav'},
#   {'file_id': '00010',
#    'video_path': 'id00528/GpB5i41hye4/00010.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00010.wav'},
#   {'file_id': '00011',
#    'video_path': 'id00528/GpB5i41hye4/00011.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00011.wav'},
#   {'file_id': '00012',
#    'video_path': 'id00528/GpB5i41hye4/00012.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00012.wav'},
#   {'file_id': '00013',
#    'video_path': 'id00528/GpB5i41hye4/00013.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00013.wav'},
#   {'file_id': '00014',
#    'video_path': 'id00528/GpB5i41hye4/00014.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00014.wav'},
#   {'file_id': '00015',
#    'video_path': 'id00528/GpB5i41hye4/00015.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00015.wav'},
#   {'file_id': '00016',
#    'video_path': 'id00528/GpB5i41hye4/00016.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00016.wav'},
#   {'file_id': '00017',
#    'video_path': 'id00528/GpB5i41hye4/00017.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00017.wav'},
#   {'file_id': '00018',
#    'video_path': 'id00528/GpB5i41hye4/00018.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00018.wav'},
#   {'file_id': '00019',
#    'video_path': 'id00528/GpB5i41hye4/00019.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00019.wav'},
#   {'file_id': '00020',
#    'video_path': 'id00528/GpB5i41hye4/00020.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00020.wav'},
#   {'file_id': '00021',
#    'video_path': 'id00528/GpB5i41hye4/00021.mp4',
#    'audio_path': 'id00528/GpB5i41hye4/00021.wav'}],
#  'LHNVMJ8KHZY': [{'file_id': '00022',
#    'video_path': 'id00528/LHNVMJ8KHZY/00022.mp4',
#    'audio_path': 'id00528/LHNVMJ8KHZY/00022.wav'}],
#  'M7sU759f-64': [{'file_id': '00023',
#    'video_path': 'id00528/M7sU759f-64/00023.mp4',
#    'audio_path': 'id00528/M7sU759f-64/00023.wav'},
#   {'file_id': '00024',
#    'video_path': 'id00528/M7sU759f-64/00024.mp4',
#    'audio_path': 'id00528/M7sU759f-64/00024.wav'},
#   {'file_id': '00025',
#    'video_path': 'id00528/M7sU759f-64/00025.mp4',
#    'audio_path': 'id00528/M7sU759f-64/00025.wav'},
#   {'file_id': '00026',
#    'video_path': 'id00528/M7sU759f-64/00026.mp4',
#    'audio_path': 'id00528/M7sU759f-64/00026.wav'}],
#  'Pc3BS3swJrQ': [{'file_id': '00027',
#    'video_path': 'id00528/Pc3BS3swJrQ/00027.mp4',
#    'audio_path': 'id00528/Pc3BS3swJrQ/00027.wav'},
#   {'file_id': '00028',
#    'video_path': 'id00528/Pc3BS3swJrQ/00028.mp4',
#    'audio_path': 'id00528/Pc3BS3swJrQ/00028.wav'},
#   {'file_id': '00029',
#    'video_path': 'id00528/Pc3BS3swJrQ/00029.mp4',
#    'audio_path': 'id00528/Pc3BS3swJrQ/00029.wav'}],
#  'VcNGWIcY_Cs': [{'file_id': '00030',
#    'video_path': 'id00528/VcNGWIcY_Cs/00030.mp4',
#    'audio_path': 'id00528/VcNGWIcY_Cs/00030.wav'},
#   {'file_id': '00031',
#    'video_path': 'id00528/VcNGWIcY_Cs/00031.mp4',
#    'audio_path': 'id00528/VcNGWIcY_Cs/00031.wav'},
#   {'file_id': '00032',
#    'video_path': 'id00528/VcNGWIcY_Cs/00032.mp4',
#    'audio_path': 'id00528/VcNGWIcY_Cs/00032.wav'},
#   {'file_id': '00033',
#    'video_path': 'id00528/VcNGWIcY_Cs/00033.mp4',
#    'audio_path': 'id00528/VcNGWIcY_Cs/00033.wav'}],
#  'bD7Suz509y4': [{'file_id': '00034',
#    'video_path': 'id00528/bD7Suz509y4/00034.mp4',
#    'audio_path': 'id00528/bD7Suz509y4/00034.wav'},
#   {'file_id': '00035',
#    'video_path': 'id00528/bD7Suz509y4/00035.mp4',
#    'audio_path': 'id00528/bD7Suz509y4/00035.wav'},
#   {'file_id': '00036',
#    'video_path': 'id00528/bD7Suz509y4/00036.mp4',
#    'audio_path': 'id00528/bD7Suz509y4/00036.wav'}],
#  'cAOz2B3eGQ4': [{'file_id': '00037',
#    'video_path': 'id00528/cAOz2B3eGQ4/00037.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00037.wav'},
#   {'file_id': '00038',
#    'video_path': 'id00528/cAOz2B3eGQ4/00038.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00038.wav'},
#   {'file_id': '00039',
#    'video_path': 'id00528/cAOz2B3eGQ4/00039.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00039.wav'},
#   {'file_id': '00040',
#    'video_path': 'id00528/cAOz2B3eGQ4/00040.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00040.wav'},
#   {'file_id': '00041',
#    'video_path': 'id00528/cAOz2B3eGQ4/00041.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00041.wav'},
#   {'file_id': '00042',
#    'video_path': 'id00528/cAOz2B3eGQ4/00042.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00042.wav'},
#   {'file_id': '00043',
#    'video_path': 'id00528/cAOz2B3eGQ4/00043.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00043.wav'},
#   {'file_id': '00044',
#    'video_path': 'id00528/cAOz2B3eGQ4/00044.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00044.wav'},
#   {'file_id': '00045',
#    'video_path': 'id00528/cAOz2B3eGQ4/00045.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00045.wav'},
#   {'file_id': '00046',
#    'video_path': 'id00528/cAOz2B3eGQ4/00046.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00046.wav'},
#   {'file_id': '00047',
#    'video_path': 'id00528/cAOz2B3eGQ4/00047.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00047.wav'},
#   {'file_id': '00048',
#    'video_path': 'id00528/cAOz2B3eGQ4/00048.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00048.wav'},
#   {'file_id': '00049',
#    'video_path': 'id00528/cAOz2B3eGQ4/00049.mp4',
#    'audio_path': 'id00528/cAOz2B3eGQ4/00049.wav'}],
#  'dr3rUu6ZS_o': [{'file_id': '00050',
#    'video_path': 'id00528/dr3rUu6ZS_o/00050.mp4',
#    'audio_path': 'id00528/dr3rUu6ZS_o/00050.wav'}],
#  'h-TlOkl8Mtc': [{'file_id': '00051',
#    'video_path': 'id00528/h-TlOkl8Mtc/00051.mp4',
#    'audio_path': 'id00528/h-TlOkl8Mtc/00051.wav'},
#   {'file_id': '00052',
#    'video_path': 'id00528/h-TlOkl8Mtc/00052.mp4',
#    'audio_path': 'id00528/h-TlOkl8Mtc/00052.wav'},
#   {'file_id': '00053',
#    'video_path': 'id00528/h-TlOkl8Mtc/00053.mp4',
#    'audio_path': 'id00528/h-TlOkl8Mtc/00053.wav'},
#   {'file_id': '00054',
#    'video_path': 'id00528/h-TlOkl8Mtc/00054.mp4',
#    'audio_path': 'id00528/h-TlOkl8Mtc/00054.wav'}],
#  'j5rKOR6kQE4': [{'file_id': '00055',
#    'video_path': 'id00528/j5rKOR6kQE4/00055.mp4',
#    'audio_path': 'id00528/j5rKOR6kQE4/00055.wav'}],
#  'lcFvOnP4MrE': [{'file_id': '00056',
#    'video_path': 'id00528/lcFvOnP4MrE/00056.mp4',
#    'audio_path': 'id00528/lcFvOnP4MrE/00056.wav'},
#   {'file_id': '00057',
#    'video_path': 'id00528/lcFvOnP4MrE/00057.mp4',
#    'audio_path': 'id00528/lcFvOnP4MrE/00057.wav'}],
#  'm1Q-ilJvI0U': [{'file_id': '00058',
#    'video_path': 'id00528/m1Q-ilJvI0U/00058.mp4',
#    'audio_path': 'id00528/m1Q-ilJvI0U/00058.wav'}]}

# %%
len(train_list["id00528"])
# Out:
# 15
